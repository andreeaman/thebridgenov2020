# %%
import numpy as np
import sklearn.metrics as metrics
#importing the Linear Regression Algorithm
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

def regression_results(y_true, y_pred):

    # Regression metrics
    explained_variance=metrics.explained_variance_score(y_true, y_pred)
    mean_absolute_error=metrics.mean_absolute_error(y_true, y_pred) 
    mse=metrics.mean_squared_error(y_true, y_pred) 
    mean_squared_log_error=metrics.mean_squared_log_error(y_true, y_pred)
    median_absolute_error=metrics.median_absolute_error(y_true, y_pred)
    r2=metrics.r2_score(y_true, y_pred)

    print('explained_variance: ', round(explained_variance,4))  # Si se acerca a 1, habrá aprendido todos los patrones de nuestro modelo.  
    print('mean_squared_log_error: ', round(mean_squared_log_error,4))
    print('r2: ', round(r2,4))
    print('MAE: ', round(mean_absolute_error,4))
    print('MSE: ', round(mse,4))
    print('RMSE: ', round(np.sqrt(mse),4))

# %%
X = 2 * np.random.rand(1000, 1) 
X = X.reshape(-1, 1)
y = 4 + 3 * X + np.random.randn(1000, 1)

plt.scatter(X, y, color='b')

# %%
linear_model = LinearRegression()
linear_model.fit(X, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

plt.scatter(X_train, y_train, color='b')

# %%
regression_results(y_true=y_test, y_pred=linear_model.predict(X_test))
# Out:
# explained_variance:  0.676
# mean_squared_log_error:  0.022
# r2:  0.6756
# MAE:  0.8486
# MSE:  1.1444
# RMSE:  1.0698

# %%
linear_model.score(X, y)
# Out:
# 0.7215875818582276

# %% [markdown]
# ### Regression model based on ordinary least squares
#
# #### Ejemplo de conceptos estadísticos

# %%
import statsmodels.api as sm

model = sm.OLS(y, X)
model.fit()
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                      y   R-squared (uncentered):                   0.909
# Model:                            OLS   Adj. R-squared (uncentered):              0.909
# Method:                 Least Squares   F-statistic:                          1.004e+04
# Date:                Tue, 01 Sep 2020   Prob (F-statistic):                        0.00
# Time:                        17:09:49   Log-Likelihood:                         -2221.6
# No. Observations:                1000   AIC:                                      4445.
# Df Residuals:                     999   BIC:                                      4450.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             5.9378      0.059    100.179      0.000       5.822       6.054
# ==============================================================================
# Omnibus:                       66.730   Durbin-Watson:                   1.659
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               24.578
# Skew:                           0.068   Prob(JB):                     4.60e-06
# Kurtosis:                       2.244   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """
