# %% [markdown]
# ## API con token

# %% [markdown]
# _El maravilloso mundo de las_ **APIs**
# ### o EL RETORNO DE JSON

# %% [markdown]
# Listado de **APIs** for free:
# https://github.com/public-apis/public-apis

# %%
import json
import requests

# %%
json_fullpath = "settings_passwords.json"
# settings.json estará en el .gitignore

# %%
with open(json_fullpath, "r+") as outfile:
    json_readed = json.load(outfile)
json_readed
# Out:
# {'CLIENT': 'KZWZYG43Q4LLZQ2RS5JNN1Q3YRCYEZHMKH0ILOZNNBNPM25Y',
#  'API_KEY': 'CBUQ5B10L4CNHGLXXM2TUV0AVH341ADAJ3DWTZSUJB0NAD5M'}

# %% [markdown]
# **DOCUMENTACIÓN DE LA API**
#
#
# --> https://developer.foursquare.com/docs/places-api/ <--

# %%
url = 'https://api.foursquare.com/v2/venues/explore'

# más códigos de categorías
# https://developer.foursquare.com/docs/build-with-foursquare/categories/

# irish pub
irish_rest = "52e81612bcbc57f1066b7a06"

# para sacar las coordenadas podrías usar una API pero también...
# https://www.123coordenadas.com/coordinates/

lat = 40.4226767
lon = -3.6922754

# %% [markdown]
# https://developer.foursquare.com/docs/places-api/getting-started/

# %%
# Lo importante, todas las APIs con token tienen una forma de acceder a ellas. La información pertinente a cada una de ellas viene (o debería venir) en su documentación

params = {"client_id": json_readed["CLIENT"],
  "client_secret": json_readed["API_KEY"],
  "v":"20180323",
  "ll": f'{lat},{lon}',
  "section": "food",
  # options --> food, drinks, coffee, shops, arts, outdoors, sights, trending
  "limit":100
}

# %%
resp = requests.get(url=url, params=params)
data = json.loads(resp.text)

# %%
data
# Out:
# {'meta': {'code': 200, 'requestId': '5fd733aa9df2156adb600822'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'}]},
#   'suggestedRadius': 644,
#   'headerLocation': 'Chueca',
#   'headerFullLocation': 'Chueca, Madrid',
#   'headerLocationGranularity': 'neighborhood',
#   'query': 'food',
#   'totalResults': 203,
#   'suggestedBounds': {'ne': {'lat': 40.42757324545612,
#     'lng': -3.6843459186013936},
#    'sw': {'lat': 40.4176272201219, 'lng': -3.6992759693953072}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5ac924f0a22db76045072b51',
#        'name': 'Charrua',
#        'contact': {},
#        'location': {'lat': 40.422416,
#         'lng': -3.693999,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.422416,
#           'lng': -3.693999}],
#         'distance': 148,
#         'postalCode': '28004',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['28004 Madrid Madrid', 'España']},
#        'categories': [{'id': '4bf58dd8d48988d1df931735',
#          'name': 'BBQ Joint',
#          'pluralName': 'BBQ Joints',
#          'shortName': 'BBQ',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-3-5ac924f0a22db76045072b51-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '57274306498ecb4252a70a34',
#        'name': 'Cannibal Raw Bar',
#        'contact': {},
#        'location': {'address': 'Calle Almirante 12',
#         'crossStreet': 'Calle Conde de Xiquena',
#         'lat': 40.42250153573088,
#         'lng': -3.694248172533777,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.42250153573088,
#           'lng': -3.694248172533777}],
#         'distance': 168,
#         'postalCode': '28004',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Calle Almirante 12 (Calle Conde de Xiquena)',
#          '28004 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d150941735',
#          'name': 'Spanish Restaurant',
#          'pluralName': 'Spanish Restaurants',
#          'shortName': 'Spanish',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/spanish_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-3-57274306498ecb4252a70a34-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4adcda3af964a5200a3d21e3',
#        'name': 'Pelotari',
#        'contact': {},
#        'location': {'address': 'P. de Recoletos, 3',
#         'lat': 40.42222852507288,
#         'lng': -3.6907204539990075,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.42222852507288,
#           'lng': -3.6907204539990075}],
#         'distance': 140,
#         'postalCode': '28001',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['P. de Recoletos, 3',
#          '28001 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d150941735',
#          'name': 'Spanish Restaurant',
#          'pluralName': 'Spanish Restaurants',
#          'shortName': 'Spanish',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/spanish_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-3-4adcda3af964a5200a3d21e3-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '54243b81498e0ccd92215778',
#        'name': 'Doki Doki',
#        'contact': {},
#        'location': {'address': 'Calle Villalar, 4',
#         'lat': 40.42116858895287,
#         'lng': -3.689797446212131,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.42116858895287,
#           'lng': -3.689797446212131}],
#         'distance': 268,
#         'postalCode': '28001',
#         'cc': 'ES',
#         'neighborhood': 'Recoletos',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Calle Villalar, 4',
#          '28001 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d111941735',
#          'name': 'Japanese Restaurant',
#          'pluralName': 'Japanese Restaurants',
#          'shortName': 'Japanese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-3-54243b81498e0ccd92215778-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5458f499498ea9af6f9874ea',
#        'name': 'la vaca y la huerta',
#        'contact': {},
#        'location': {'address': 'recoletos 13',
#         'lat': 40.42169749420284,
#         'lng': -3.689684868069797,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.42169749420284,
#           'lng': -3.689684868069797}],
#         'distance': 245,
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['recoletos 13', 'Madrid Madrid', 'España']},
#        'categories': [{'id': '4bf58dd8d48988d150941735',
#          'name': 'Spanish Restaurant',
#          'pluralName': 'Spanish Restaurants',
#          'shortName': 'Spanish',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/spanish_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-3-5458f499498ea9af6f9874ea-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e7c7a52149595a17e5735d7',
#        'name': 'New York Burger',
#        'contact': {},
#        'location': {'address': 'Calle de Recoletos, 4',
#         'lat': 40.42212085931879,
#         'lng': -3.6907109051907323,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.42212085931879,
#           'lng': -3.6907109051907323}],
#         'distance': 146,
#         'postalCode': '28004',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Calle de Recoletos, 4',
#          '28004 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d16c941735',
#          'name': 'Burger Joint',
#          'pluralName': 'Burger Joints',
#          'shortName': 'Burgers',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-3-4e7c7a52149595a17e5735d7-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '551c4fbd498eb45d01705086',
#        'name': 'Flavia Restaurante & Bar',
#        'contact': {},
#        'location': {'address': 'C. Gil de Santivañes, 2',
#         'lat': 40.42247356448254,
#         'lng': -3.689587219885726,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.42247356448254,
#           'lng': -3.689587219885726}],
#         'distance': 228,
#         'postalCode': '28001',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Gil de Santivañes, 2',
#          '28001 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-3-551c4fbd498eb45d01705086-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '58a1821a5cab2f7fd651f66d',
#        'name': 'Panod',
#        'contact': {},
#        'location': {'address': 'Calle Prim 1',
#         'lat': 40.42196050145854,
#         'lng': -3.6954788629561257,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.42196050145854,
#           'lng': -3.6954788629561257}],
#         'distance': 282,
#         'postalCode': '28004',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Calle Prim 1', '28004 Madrid Madrid', 'España']},
#        'categories': [{'id': '4bf58dd8d48988d16a941735',
#          'name': 'Bakery',
#          'pluralName': 'Bakeries',
#          'shortName': 'Bakery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-3-58a1821a5cab2f7fd651f66d-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '57d3b734cd10a53b95eb51e1',
#        'name': 'celicioso',
#        'contact': {},
#        'location': {'address': 'Calle del Barquillo 19',
#         'lat': 40.4221118727551,
#         'lng': -3.695725917401657,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.4221118727551,
#           'lng': -3.695725917401657}],
#         'distance': 299,
#         'postalCode': '28004',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Calle del Barquillo 19',
#          '28004 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d16a941735',
#          'name': 'Bakery',
#          'pluralName': 'Bakeries',
#          'shortName': 'Bakery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-3-57d3b734cd10a53b95eb51e1-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5b966594ba57b4002cce85e0',
#        'name': 'Raimunda',
#        'contact': {},
#        'location': {'lat': 40.420203,
#         'lng': -3.692069,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.420203,
#           'lng': -3.692069}],
#         'distance': 275,
#         'postalCode': '28001',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['28001 Madrid Madrid', 'España']},
#        'categories': [{'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'shortName': 'Restaurant',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-3-5b966594ba57b4002cce85e0-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '505cca21e4b0e43317ba3353',
#        'name': 'Banzai',
#        'contact': {},
#        'location': {'address': 'C. Recoletos, 10',
#         'lat': 40.421920385467324,
#         'lng': -3.69024558983566,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.421920385467324,
#           'lng': -3.69024558983566}],
#         'distance': 191,
#         'postalCode': '28001',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Recoletos, 10',
#          '28001 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d111941735',
#          'name': 'Japanese Restaurant',
#          'pluralName': 'Japanese Restaurants',
#          'shortName': 'Japanese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-3-505cca21e4b0e43317ba3353-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '53b5ba78498e41ea4e231ee4',
#        'name': 'DSTAgE',
#        'contact': {},
#        'location': {'address': 'C. Regueros, 8',
#         'lat': 40.42472945683953,
#         'lng': -3.6963052685894597,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.42472945683953,
#           'lng': -3.6963052685894597}],
#         'distance': 410,
#         'postalCode': '28004',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Regueros, 8',
#          '28004 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'shortName': 'Restaurant',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-3-53b5ba78498e41ea4e231ee4-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '58bc17e57ff1e457a725d859',
#        'name': 'Mamá Chicó',
#        'contact': {},
#        'location': {'address': 'Calle Recoletos, 10',
#         'lat': 40.421703,
#         'lng': -3.6898375,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.421703,
#           'lng': -3.6898375}],
#         'distance': 233,
#         'cc': 'ES',
#         'neighborhood': 'Recoletos',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Calle Recoletos, 10',
#          'Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'shortName': 'Restaurant',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-3-58bc17e57ff1e457a725d859-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '573dbaf9498e3b76737e8a68',
#        'name': 'Habanera',
#        'contact': {},
#        'location': {'address': 'Calle de Génova, 28',
#         'lat': 40.42548355338372,
#         'lng': -3.6913277741268846,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.42548355338372,
#           'lng': -3.6913277741268846}],
#         'distance': 322,
#         'postalCode': '28004',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Calle de Génova, 28',
#          '28004 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'shortName': 'Restaurant',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-3-573dbaf9498e3b76737e8a68-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '59f56394446ea631a09aa6fe',
#        'name': 'niMÚ Barquillo',
#        'contact': {},
#        'location': {'address': 'C. Barquillo 40',
#         'lat': 40.42394311013904,
#         'lng': -3.695424199104309,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.42394311013904,
#           'lng': -3.695424199104309}],
#         'distance': 301,
#         'postalCode': '28004',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Barquillo 40',
#          '28004 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d150941735',
#          'name': 'Spanish Restaurant',
#          'pluralName': 'Spanish Restaurants',
#          'shortName': 'Spanish',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/spanish_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-3-59f56394446ea631a09aa6fe-14'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b781a82f964a520f0b52ee3',
#        'name': 'La Tavernetta',
#        'contact': {},
#        'location': {'address': 'C. Orellana, 17',
#         'lat': 40.42607635914717,
#         'lng': -3.6941559395385597,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.42607635914717,
#           'lng': -3.6941559395385597}],
#         'distance': 410,
#         'postalCode': '28004',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Orellana, 17',
#          '28004 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-3-4b781a82f964a520f0b52ee3-15'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '512ca653e4b0a48edc60c6fe',
#        'name': 'a.n.E.l. Tapas & Lounge Bar',
#        'contact': {},
#        'location': {'address': 'C. Villalar, 1',
#         'lat': 40.42057350392659,
#         'lng': -3.6902831658874935,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.42057350392659,
#           'lng': -3.6902831658874935}],
#         'distance': 288,
#         'postalCode': '28001',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Villalar, 1',
#          '28001 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'shortName': 'Restaurant',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-3-512ca653e4b0a48edc60c6fe-16'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '561169a6498ec82453ff8642',
#        'name': 'Faborit',
#        'contact': {},
#        'location': {'address': 'Alcalá 61',
#         'lat': 40.41971275428974,
#         'lng': -3.6911013361033387,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.41971275428974,
#           'lng': -3.6911013361033387}],
#         'distance': 344,
#         'postalCode': '28014',
#         'cc': 'ES',
#         'neighborhood': 'Recoletos',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Alcalá 61', '28014 Madrid Madrid', 'España']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-3-561169a6498ec82453ff8642-17'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d9c13139f86a1cde3b069ab',
#        'name': 'El Cafetin De Fernando VI',
#        'contact': {},
#        'location': {'address': 'Fernando VI',
#         'lat': 40.42484543685317,
#         'lng': -3.6957562579032963,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.42484543685317,
#           'lng': -3.6957562579032963}],
#         'distance': 381,
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Fernando VI', 'Madrid Madrid', 'España']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-3-4d9c13139f86a1cde3b069ab-18'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e75e5b2e4cd32543782026f',
#        'name': 'Magasand Columela',
#        'contact': {},
#        'location': {'address': 'C. Columela, 4',
#         'lat': 40.421089,
#         'lng': -3.687984,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.421089,
#           'lng': -3.687984}],
#         'distance': 404,
#         'postalCode': '28001',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Columela, 4',
#          '28001 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-3-4e75e5b2e4cd32543782026f-19'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cf6808cc020b60c90832075',
#        'name': 'Adolfo Dominguez Lounge Cafe',
#        'contact': {},
#        'location': {'address': 'C. Serrano, 5',
#         'crossStreet': 'C. Recoletos',
#         'lat': 40.421420464623246,
#         'lng': -3.6886059830484292,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.421420464623246,
#           'lng': -3.6886059830484292}],
#         'distance': 340,
#         'postalCode': '28001',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Serrano, 5 (C. Recoletos)',
#          '28001 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-3-4cf6808cc020b60c90832075-20'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4de78553d22dc38f1ee24b2b',
#        'name': 'El Supremo',
#        'contact': {},
#        'location': {'address': 'C. Marqués de la Ensenada',
#         'lat': 40.42384197017909,
#         'lng': -3.6928093295162947,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.42384197017909,
#           'lng': -3.6928093295162947}],
#         'distance': 137,
#         'postalCode': '28004',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Marqués de la Ensenada',
#          '28004 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4d4b7105d754a06374d81259',
#          'name': 'Food',
#          'pluralName': 'Food',
#          'shortName': 'Food',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-3-4de78553d22dc38f1ee24b2b-21'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '53c1b62a498eb5bf28f996bd',
#        'name': 'Mal de Amores',
#        'contact': {},
#        'location': {'address': 'Valgame Dios, 4',
#         'lat': 40.42225718566712,
#         'lng': -3.6966339163444717,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.42225718566712,
#           'lng': -3.6966339163444717}],
#         'distance': 372,
#         'cc': 'ES',
#         'country': 'España',
#         'formattedAddress': ['Valgame Dios, 4', 'España']},
#        'categories': [{'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'shortName': 'Restaurant',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-3-53c1b62a498eb5bf28f996bd-22'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5cf25b0406fb60002c8d15e5',
#        'name': 'Aarde',
#        'contact': {},
#        'location': {'lat': 40.419701,
#         'lng': -3.689125,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.419701,
#           'lng': -3.689125}],
#         'distance': 425,
#         'postalCode': '28014',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['28014 Madrid Madrid', 'España']},
#        'categories': [{'id': '4bf58dd8d48988d1c0941735',
#          'name': 'Mediterranean Restaurant',
#          'pluralName': 'Mediterranean Restaurants',
#          'shortName': 'Mediterranean',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mediterranean_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-3-5cf25b0406fb60002c8d15e5-23'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b7274e2f964a5206a7b2de3',
#        'name': 'Ramsés',
#        'contact': {},
#        'location': {'address': 'Pl. de la Independencia, 4',
#         'lat': 40.420447280956324,
#         'lng': -3.6889526380636446,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.420447280956324,
#           'lng': -3.6889526380636446}],
#         'distance': 375,
#         'postalCode': '28001',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Pl. de la Independencia, 4',
#          '28001 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'shortName': 'Restaurant',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '33840785'},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-3-4b7274e2f964a5206a7b2de3-24'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4eb6e73102d5f33e9330b487',
#        'name': 'Food Truck',
#        'contact': {},
#        'location': {'address': 'C. San Lucas, 11',
#         'lat': 40.42381557557015,
#         'lng': -3.6960864532494018,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.42381557557015,
#           'lng': -3.6960864532494018}],
#         'distance': 346,
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. San Lucas, 11', 'Madrid Madrid', 'España']},
#        'categories': [{'id': '4bf58dd8d48988d14e941735',
#          'name': 'American Restaurant',
#          'pluralName': 'American Restaurants',
#          'shortName': 'American',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-3-4eb6e73102d5f33e9330b487-25'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4adcda35f964a520873b21e3',
#        'name': 'El Cisne Azul',
#        'contact': {},
#        'location': {'address': 'C. Gravina, 19',
#         'lat': 40.4226125570602,
#         'lng': -3.696732565805115,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.4226125570602,
#           'lng': -3.696732565805115}],
#         'distance': 377,
#         'postalCode': '28004',
#         'cc': 'ES',
#         'neighborhood': 'Chueca',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Gravina, 19',
#          '28004 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d150941735',
#          'name': 'Spanish Restaurant',
#          'pluralName': 'Spanish Restaurants',
#          'shortName': 'Spanish',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/spanish_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-3-4adcda35f964a520873b21e3-26'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51ca2035498e6098207e6624',
#        'name': 'Vides',
#        'contact': {},
#        'location': {'address': 'C. Libertad, 12',
#         'lat': 40.42101652377878,
#         'lng': -3.6973542003338395,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.42101652377878,
#           'lng': -3.6973542003338395}],
#         'distance': 468,
#         'postalCode': '28004',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Libertad, 12',
#          '28004 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d155941735',
#          'name': 'Gastropub',
#          'pluralName': 'Gastropubs',
#          'shortName': 'Gastropub',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/gastropub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-3-51ca2035498e6098207e6624-27'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '550dd8d2498ecc23842fd54d',
#        'name': "Prep' La Crêpe",
#        'contact': {},
#        'location': {'address': 'C/ Génova, 25',
#         'lat': 40.42619324204986,
#         'lng': -3.692839342867028,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.42619324204986,
#           'lng': -3.692839342867028}],
#         'distance': 394,
#         'postalCode': '28004',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C/ Génova, 25',
#          '28004 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '52e81612bcbc57f1066b79f2',
#          'name': 'Creperie',
#          'pluralName': 'Creperies',
#          'shortName': 'Creperie',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/creperie_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '580424930'},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-3-550dd8d2498ecc23842fd54d-28'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '59bd2433805e3f5982c09476',
#        'name': "Bunny's Deli",
#        'contact': {},
#        'location': {'address': 'Calle San Gregorio 17',
#         'lat': 40.423935,
#         'lng': -3.6971583,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.423935,
#           'lng': -3.6971583}],
#         'distance': 436,
#         'postalCode': '28004',
#         'cc': 'ES',
#         'neighborhood': 'Chueca',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Calle San Gregorio 17',
#          '28004 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1d3941735',
#          'name': 'Vegetarian / Vegan Restaurant',
#          'pluralName': 'Vegetarian / Vegan Restaurants',
#          'shortName': 'Vegetarian / Vegan',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '457440977'},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-3-59bd2433805e3f5982c09476-29'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '59452002061b51682cee99b8',
#        'name': 'Canalla Bistro by Ricard Camarena',
#        'contact': {},
#        'location': {'address': 'C. Goya, 5-7, Planta 1',
#         'lat': 40.426057373983376,
#         'lng': -3.688617396245811,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.426057373983376,
#           'lng': -3.688617396245811}],
#         'distance': 487,
#         'postalCode': '28001',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Goya, 5-7, Planta 1',
#          '28001 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'shortName': 'Restaurant',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-3-59452002061b51682cee99b8-30'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5c44a7dd57a537002c8bf697',
#        'name': 'Aüakt',
#        'contact': {},
#        'location': {'lat': 40.424315,
#         'lng': -3.695449,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.424315,
#           'lng': -3.695449}],
#         'distance': 324,
#         'postalCode': '28004',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['28004 Madrid Madrid', 'España']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
# ...
#           'lng': -3.696839788805677}],
#         'distance': 420,
#         'postalCode': '28004',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Colmenares, 13 (C. San Marcos)',
#          '28004 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'shortName': 'Restaurant',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-3-55cb69be498e3c20da3ef6f5-89'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b75e1eff964a520e02b2ee3',
#        'name': 'Restaurante Arce',
#        'contact': {},
#        'location': {'address': 'C. Augusto Figueroa, 32',
#         'lat': 40.42207258933475,
#         'lng': -3.6967412061319482,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.42207258933475,
#           'lng': -3.6967412061319482}],
#         'distance': 384,
#         'postalCode': '28004',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Augusto Figueroa, 32',
#          '28004 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d150941735',
#          'name': 'Spanish Restaurant',
#          'pluralName': 'Spanish Restaurants',
#          'shortName': 'Spanish',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/spanish_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-3-4b75e1eff964a520e02b2ee3-90'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '591ffe425d0fea5ae1445497',
#        'name': 'Aloha Poké',
#        'contact': {},
#        'location': {'address': 'Calle de la Libertad 17',
#         'lat': 40.42113511381703,
#         'lng': -3.6973795495793205,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.42113511381703,
#           'lng': -3.6973795495793205}],
#         'distance': 465,
#         'postalCode': '28004',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Calle de la Libertad 17',
#          '28004 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '52e81612bcbc57f1066b79fe',
#          'name': 'Hawaiian Restaurant',
#          'pluralName': 'Hawaiian Restaurants',
#          'shortName': 'Hawaiian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '423049614'},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-3-591ffe425d0fea5ae1445497-91'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5650e689498e59806e43a30f',
#        'name': 'Ôven Mozzarella Bar',
#        'contact': {},
#        'location': {'address': 'Calle Gran Via, 6',
#         'lat': 40.41924524133954,
#         'lng': -3.6978500877927485,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.41924524133954,
#           'lng': -3.6978500877927485}],
#         'distance': 607,
#         'postalCode': '28013',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Calle Gran Via, 6',
#          '28013 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-3-5650e689498e59806e43a30f-92'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '57ee650fcd1039e6f39b65f8',
#        'name': 'Tampu',
#        'contact': {},
#        'location': {'address': 'C. Prim, 13',
#         'lat': 40.42199569954899,
#         'lng': -3.693545458260162,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.42199569954899,
#           'lng': -3.693545458260162}],
#         'distance': 131,
#         'cc': 'ES',
#         'country': 'España',
#         'formattedAddress': ['C. Prim, 13', 'España']},
#        'categories': [{'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'shortName': 'Restaurant',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-3-57ee650fcd1039e6f39b65f8-93'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4adcda3af964a5205b3d21e3',
#        'name': 'Arabia',
#        'contact': {},
#        'location': {'address': 'c/ Piamonte, 12',
#         'lat': 40.42305,
#         'lng': -3.6950688,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.42305,
#           'lng': -3.6950688}],
#         'distance': 240,
#         'postalCode': '28004',
#         'cc': 'ES',
#         'neighborhood': 'Chueca',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['c/ Piamonte, 12',
#          '28004 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1c3941735',
#          'name': 'Moroccan Restaurant',
#          'pluralName': 'Moroccan Restaurants',
#          'shortName': 'Moroccan',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/moroccan_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-3-4adcda3af964a5205b3d21e3-94'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b842bf2f964a5205b2531e3',
#        'name': 'La Castafiore',
#        'contact': {},
#        'location': {'address': 'C. Marqués de Monasterio, 5',
#         'lat': 40.4231948184309,
#         'lng': -3.6934970747678526,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.4231948184309,
#           'lng': -3.6934970747678526}],
#         'distance': 118,
#         'postalCode': '28004',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Marqués de Monasterio, 5',
#          '28004 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'shortName': 'Restaurant',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-3-4b842bf2f964a5205b2531e3-95'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '538ce5df498eb2165bface85',
#        'name': 'Yakitoro',
#        'contact': {},
#        'location': {'address': 'C. de la Reina, 41',
#         'lat': 40.419647701387746,
#         'lng': -3.697201837743589,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.419647701387746,
#           'lng': -3.697201837743589}],
#         'distance': 536,
#         'postalCode': '28001',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. de la Reina, 41',
#          '28001 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d111941735',
#          'name': 'Japanese Restaurant',
#          'pluralName': 'Japanese Restaurants',
#          'shortName': 'Japanese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-3-538ce5df498eb2165bface85-96'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5710f195498e1bdf3422620a',
#        'name': 'cripeka',
#        'contact': {},
#        'location': {'lat': 40.42633069472612,
#         'lng': -3.696475115325826,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.42633069472612,
#           'lng': -3.696475115325826}],
#         'distance': 540,
#         'cc': 'ES',
#         'country': 'España',
#         'formattedAddress': ['España']},
#        'categories': [{'id': '4bf58dd8d48988d16a941735',
#          'name': 'Bakery',
#          'pluralName': 'Bakeries',
#          'shortName': 'Bakery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-3-5710f195498e1bdf3422620a-97'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '531f8e56498e6a649718295b',
#        'name': 'La Mafia se sienta a la mesa',
#        'contact': {},
#        'location': {'address': 'C. Goya, 5',
#         'lat': 40.425704898432215,
#         'lng': -3.688945279786655,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.425704898432215,
#           'lng': -3.688945279786655}],
#         'distance': 439,
#         'postalCode': '28001',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Goya, 5', '28001 Madrid Madrid', 'España']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-3-531f8e56498e6a649718295b-98'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '554e686d498e1d5fa7d64d0c',
#        'name': 'Mandarin Japanese Kitchen',
#        'contact': {},
#        'location': {'address': 'Paseo De Recoletos, 37',
#         'lat': 40.42434371838993,
#         'lng': -3.6913664650128597,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.42434371838993,
#           'lng': -3.6913664650128597}],
#         'distance': 200,
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Paseo De Recoletos, 37',
#          'Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d111941735',
#          'name': 'Japanese Restaurant',
#          'pluralName': 'Japanese Restaurants',
#          'shortName': 'Japanese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-3-554e686d498e1d5fa7d64d0c-99'}]}]}}

# %%
# Para guardar en un archivo local
import pandas as pd
df = pd.DataFrame(data)
df.to_csv("toda_informacion.csv")

# %%
data["response"].keys()
# Out:
# dict_keys(['suggestedFilters', 'suggestedRadius', 'headerLocation', 'headerFullLocation', 'headerLocationGranularity', 'query', 'totalResults', 'suggestedBounds', 'groups'])

# %%
data["response"]
# Out:
# {'suggestedFilters': {'header': 'Tap to show:',
#   'filters': [{'name': 'Open now', 'key': 'openNow'}]},
#  'suggestedRadius': 644,
#  'headerLocation': 'Chueca',
#  'headerFullLocation': 'Chueca, Madrid',
#  'headerLocationGranularity': 'neighborhood',
#  'query': 'food',
#  'totalResults': 203,
#  'suggestedBounds': {'ne': {'lat': 40.42757324545612,
#    'lng': -3.6843459186013936},
#   'sw': {'lat': 40.4176272201219, 'lng': -3.6992759693953072}},
#  'groups': [{'type': 'Recommended Places',
#    'name': 'recommended',
#    'items': [{'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '5ac924f0a22db76045072b51',
#       'name': 'Charrua',
#       'contact': {},
#       'location': {'lat': 40.422416,
#        'lng': -3.693999,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.422416,
#          'lng': -3.693999}],
#        'distance': 148,
#        'postalCode': '28004',
#        'cc': 'ES',
#        'city': 'Madrid',
#        'state': 'Madrid',
#        'country': 'España',
#        'formattedAddress': ['28004 Madrid Madrid', 'España']},
#       'categories': [{'id': '4bf58dd8d48988d1df931735',
#         'name': 'BBQ Joint',
#         'pluralName': 'BBQ Joints',
#         'shortName': 'BBQ',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': False,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'referralId': 'e-3-5ac924f0a22db76045072b51-0'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '57274306498ecb4252a70a34',
#       'name': 'Cannibal Raw Bar',
#       'contact': {},
#       'location': {'address': 'Calle Almirante 12',
#        'crossStreet': 'Calle Conde de Xiquena',
#        'lat': 40.42250153573088,
#        'lng': -3.694248172533777,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.42250153573088,
#          'lng': -3.694248172533777}],
#        'distance': 168,
#        'postalCode': '28004',
#        'cc': 'ES',
#        'city': 'Madrid',
#        'state': 'Madrid',
#        'country': 'España',
#        'formattedAddress': ['Calle Almirante 12 (Calle Conde de Xiquena)',
#         '28004 Madrid Madrid',
#         'España']},
#       'categories': [{'id': '4bf58dd8d48988d150941735',
#         'name': 'Spanish Restaurant',
#         'pluralName': 'Spanish Restaurants',
#         'shortName': 'Spanish',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/spanish_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': False,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'referralId': 'e-3-57274306498ecb4252a70a34-1'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '4adcda3af964a5200a3d21e3',
#       'name': 'Pelotari',
#       'contact': {},
#       'location': {'address': 'P. de Recoletos, 3',
#        'lat': 40.42222852507288,
#        'lng': -3.6907204539990075,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.42222852507288,
#          'lng': -3.6907204539990075}],
#        'distance': 140,
#        'postalCode': '28001',
#        'cc': 'ES',
#        'city': 'Madrid',
#        'state': 'Madrid',
#        'country': 'España',
#        'formattedAddress': ['P. de Recoletos, 3',
#         '28001 Madrid Madrid',
#         'España']},
#       'categories': [{'id': '4bf58dd8d48988d150941735',
#         'name': 'Spanish Restaurant',
#         'pluralName': 'Spanish Restaurants',
#         'shortName': 'Spanish',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/spanish_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': False,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'referralId': 'e-3-4adcda3af964a5200a3d21e3-2'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '54243b81498e0ccd92215778',
#       'name': 'Doki Doki',
#       'contact': {},
#       'location': {'address': 'Calle Villalar, 4',
#        'lat': 40.42116858895287,
#        'lng': -3.689797446212131,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.42116858895287,
#          'lng': -3.689797446212131}],
#        'distance': 268,
#        'postalCode': '28001',
#        'cc': 'ES',
#        'neighborhood': 'Recoletos',
#        'city': 'Madrid',
#        'state': 'Madrid',
#        'country': 'España',
#        'formattedAddress': ['Calle Villalar, 4',
#         '28001 Madrid Madrid',
#         'España']},
#       'categories': [{'id': '4bf58dd8d48988d111941735',
#         'name': 'Japanese Restaurant',
#         'pluralName': 'Japanese Restaurants',
#         'shortName': 'Japanese',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': False,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'referralId': 'e-3-54243b81498e0ccd92215778-3'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '5458f499498ea9af6f9874ea',
#       'name': 'la vaca y la huerta',
#       'contact': {},
#       'location': {'address': 'recoletos 13',
#        'lat': 40.42169749420284,
#        'lng': -3.689684868069797,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.42169749420284,
#          'lng': -3.689684868069797}],
#        'distance': 245,
#        'cc': 'ES',
#        'city': 'Madrid',
#        'state': 'Madrid',
#        'country': 'España',
#        'formattedAddress': ['recoletos 13', 'Madrid Madrid', 'España']},
#       'categories': [{'id': '4bf58dd8d48988d150941735',
#         'name': 'Spanish Restaurant',
#         'pluralName': 'Spanish Restaurants',
#         'shortName': 'Spanish',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/spanish_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': False,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'referralId': 'e-3-5458f499498ea9af6f9874ea-4'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '4e7c7a52149595a17e5735d7',
#       'name': 'New York Burger',
#       'contact': {},
#       'location': {'address': 'Calle de Recoletos, 4',
#        'lat': 40.42212085931879,
#        'lng': -3.6907109051907323,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.42212085931879,
#          'lng': -3.6907109051907323}],
#        'distance': 146,
#        'postalCode': '28004',
#        'cc': 'ES',
#        'city': 'Madrid',
#        'state': 'Madrid',
#        'country': 'España',
#        'formattedAddress': ['Calle de Recoletos, 4',
#         '28004 Madrid Madrid',
#         'España']},
#       'categories': [{'id': '4bf58dd8d48988d16c941735',
#         'name': 'Burger Joint',
#         'pluralName': 'Burger Joints',
#         'shortName': 'Burgers',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': False,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'referralId': 'e-3-4e7c7a52149595a17e5735d7-5'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '551c4fbd498eb45d01705086',
#       'name': 'Flavia Restaurante & Bar',
#       'contact': {},
#       'location': {'address': 'C. Gil de Santivañes, 2',
#        'lat': 40.42247356448254,
#        'lng': -3.689587219885726,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.42247356448254,
#          'lng': -3.689587219885726}],
#        'distance': 228,
#        'postalCode': '28001',
#        'cc': 'ES',
#        'city': 'Madrid',
#        'state': 'Madrid',
#        'country': 'España',
#        'formattedAddress': ['C. Gil de Santivañes, 2',
#         '28001 Madrid Madrid',
#         'España']},
#       'categories': [{'id': '4bf58dd8d48988d110941735',
#         'name': 'Italian Restaurant',
#         'pluralName': 'Italian Restaurants',
#         'shortName': 'Italian',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': False,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'referralId': 'e-3-551c4fbd498eb45d01705086-6'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '58a1821a5cab2f7fd651f66d',
#       'name': 'Panod',
#       'contact': {},
#       'location': {'address': 'Calle Prim 1',
#        'lat': 40.42196050145854,
#        'lng': -3.6954788629561257,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.42196050145854,
#          'lng': -3.6954788629561257}],
#        'distance': 282,
#        'postalCode': '28004',
#        'cc': 'ES',
#        'city': 'Madrid',
#        'state': 'Madrid',
#        'country': 'España',
#        'formattedAddress': ['Calle Prim 1', '28004 Madrid Madrid', 'España']},
#       'categories': [{'id': '4bf58dd8d48988d16a941735',
#         'name': 'Bakery',
#         'pluralName': 'Bakeries',
#         'shortName': 'Bakery',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': False,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'referralId': 'e-3-58a1821a5cab2f7fd651f66d-7'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '57d3b734cd10a53b95eb51e1',
#       'name': 'celicioso',
#       'contact': {},
#       'location': {'address': 'Calle del Barquillo 19',
#        'lat': 40.4221118727551,
#        'lng': -3.695725917401657,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.4221118727551,
#          'lng': -3.695725917401657}],
#        'distance': 299,
#        'postalCode': '28004',
#        'cc': 'ES',
#        'city': 'Madrid',
#        'state': 'Madrid',
#        'country': 'España',
#        'formattedAddress': ['Calle del Barquillo 19',
#         '28004 Madrid Madrid',
#         'España']},
#       'categories': [{'id': '4bf58dd8d48988d16a941735',
#         'name': 'Bakery',
#         'pluralName': 'Bakeries',
#         'shortName': 'Bakery',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': False,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'referralId': 'e-3-57d3b734cd10a53b95eb51e1-8'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '5b966594ba57b4002cce85e0',
#       'name': 'Raimunda',
#       'contact': {},
#       'location': {'lat': 40.420203,
#        'lng': -3.692069,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.420203,
#          'lng': -3.692069}],
#        'distance': 275,
#        'postalCode': '28001',
#        'cc': 'ES',
#        'city': 'Madrid',
#        'state': 'Madrid',
#        'country': 'España',
#        'formattedAddress': ['28001 Madrid Madrid', 'España']},
#       'categories': [{'id': '4bf58dd8d48988d1c4941735',
#         'name': 'Restaurant',
#         'pluralName': 'Restaurants',
#         'shortName': 'Restaurant',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': False,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'referralId': 'e-3-5b966594ba57b4002cce85e0-9'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '505cca21e4b0e43317ba3353',
#       'name': 'Banzai',
#       'contact': {},
#       'location': {'address': 'C. Recoletos, 10',
#        'lat': 40.421920385467324,
#        'lng': -3.69024558983566,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.421920385467324,
#          'lng': -3.69024558983566}],
#        'distance': 191,
#        'postalCode': '28001',
#        'cc': 'ES',
#        'city': 'Madrid',
#        'state': 'Madrid',
#        'country': 'España',
#        'formattedAddress': ['C. Recoletos, 10',
#         '28001 Madrid Madrid',
#         'España']},
#       'categories': [{'id': '4bf58dd8d48988d111941735',
#         'name': 'Japanese Restaurant',
#         'pluralName': 'Japanese Restaurants',
#         'shortName': 'Japanese',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': False,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'referralId': 'e-3-505cca21e4b0e43317ba3353-10'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '53b5ba78498e41ea4e231ee4',
#       'name': 'DSTAgE',
#       'contact': {},
#       'location': {'address': 'C. Regueros, 8',
#        'lat': 40.42472945683953,
#        'lng': -3.6963052685894597,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.42472945683953,
#          'lng': -3.6963052685894597}],
#        'distance': 410,
#        'postalCode': '28004',
#        'cc': 'ES',
#        'city': 'Madrid',
#        'state': 'Madrid',
#        'country': 'España',
#        'formattedAddress': ['C. Regueros, 8',
#         '28004 Madrid Madrid',
#         'España']},
#       'categories': [{'id': '4bf58dd8d48988d1c4941735',
#         'name': 'Restaurant',
#         'pluralName': 'Restaurants',
#         'shortName': 'Restaurant',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': False,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'referralId': 'e-3-53b5ba78498e41ea4e231ee4-11'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '58bc17e57ff1e457a725d859',
#       'name': 'Mamá Chicó',
#       'contact': {},
#       'location': {'address': 'Calle Recoletos, 10',
#        'lat': 40.421703,
#        'lng': -3.6898375,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.421703,
#          'lng': -3.6898375}],
#        'distance': 233,
#        'cc': 'ES',
#        'neighborhood': 'Recoletos',
#        'city': 'Madrid',
#        'state': 'Madrid',
#        'country': 'España',
#        'formattedAddress': ['Calle Recoletos, 10', 'Madrid Madrid', 'España']},
#       'categories': [{'id': '4bf58dd8d48988d1c4941735',
#         'name': 'Restaurant',
#         'pluralName': 'Restaurants',
#         'shortName': 'Restaurant',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': False,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'referralId': 'e-3-58bc17e57ff1e457a725d859-12'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '573dbaf9498e3b76737e8a68',
#       'name': 'Habanera',
#       'contact': {},
#       'location': {'address': 'Calle de Génova, 28',
#        'lat': 40.42548355338372,
#        'lng': -3.6913277741268846,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.42548355338372,
#          'lng': -3.6913277741268846}],
#        'distance': 322,
#        'postalCode': '28004',
#        'cc': 'ES',
#        'city': 'Madrid',
#        'state': 'Madrid',
#        'country': 'España',
#        'formattedAddress': ['Calle de Génova, 28',
#         '28004 Madrid Madrid',
#         'España']},
#       'categories': [{'id': '4bf58dd8d48988d1c4941735',
#         'name': 'Restaurant',
#         'pluralName': 'Restaurants',
#         'shortName': 'Restaurant',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': False,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'referralId': 'e-3-573dbaf9498e3b76737e8a68-13'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '59f56394446ea631a09aa6fe',
#       'name': 'niMÚ Barquillo',
#       'contact': {},
#       'location': {'address': 'C. Barquillo 40',
#        'lat': 40.42394311013904,
#        'lng': -3.695424199104309,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.42394311013904,
#          'lng': -3.695424199104309}],
#        'distance': 301,
#        'postalCode': '28004',
#        'cc': 'ES',
#        'city': 'Madrid',
#        'state': 'Madrid',
#        'country': 'España',
#        'formattedAddress': ['C. Barquillo 40',
#         '28004 Madrid Madrid',
#         'España']},
#       'categories': [{'id': '4bf58dd8d48988d150941735',
#         'name': 'Spanish Restaurant',
#         'pluralName': 'Spanish Restaurants',
#         'shortName': 'Spanish',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/spanish_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': False,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'referralId': 'e-3-59f56394446ea631a09aa6fe-14'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '4b781a82f964a520f0b52ee3',
#       'name': 'La Tavernetta',
#       'contact': {},
#       'location': {'address': 'C. Orellana, 17',
#        'lat': 40.42607635914717,
#        'lng': -3.6941559395385597,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.42607635914717,
#          'lng': -3.6941559395385597}],
#        'distance': 410,
#        'postalCode': '28004',
#        'cc': 'ES',
#        'city': 'Madrid',
#        'state': 'Madrid',
#        'country': 'España',
#        'formattedAddress': ['C. Orellana, 17',
#         '28004 Madrid Madrid',
#         'España']},
#       'categories': [{'id': '4bf58dd8d48988d110941735',
#         'name': 'Italian Restaurant',
#         'pluralName': 'Italian Restaurants',
#         'shortName': 'Italian',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': False,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'referralId': 'e-3-4b781a82f964a520f0b52ee3-15'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '512ca653e4b0a48edc60c6fe',
#       'name': 'a.n.E.l. Tapas & Lounge Bar',
#       'contact': {},
#       'location': {'address': 'C. Villalar, 1',
#        'lat': 40.42057350392659,
#        'lng': -3.6902831658874935,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.42057350392659,
#          'lng': -3.6902831658874935}],
#        'distance': 288,
#        'postalCode': '28001',
#        'cc': 'ES',
#        'city': 'Madrid',
#        'state': 'Madrid',
#        'country': 'España',
#        'formattedAddress': ['C. Villalar, 1',
#         '28001 Madrid Madrid',
#         'España']},
#       'categories': [{'id': '4bf58dd8d48988d1c4941735',
#         'name': 'Restaurant',
#         'pluralName': 'Restaurants',
#         'shortName': 'Restaurant',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': False,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'referralId': 'e-3-512ca653e4b0a48edc60c6fe-16'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '561169a6498ec82453ff8642',
#       'name': 'Faborit',
#       'contact': {},
#       'location': {'address': 'Alcalá 61',
#        'lat': 40.41971275428974,
#        'lng': -3.6911013361033387,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.41971275428974,
#          'lng': -3.6911013361033387}],
#        'distance': 344,
#        'postalCode': '28014',
#        'cc': 'ES',
#        'neighborhood': 'Recoletos',
#        'city': 'Madrid',
#        'state': 'Madrid',
#        'country': 'España',
#        'formattedAddress': ['Alcalá 61', '28014 Madrid Madrid', 'España']},
#       'categories': [{'id': '4bf58dd8d48988d16d941735',
#         'name': 'Café',
#         'pluralName': 'Cafés',
#         'shortName': 'Café',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': False,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'referralId': 'e-3-561169a6498ec82453ff8642-17'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '4d9c13139f86a1cde3b069ab',
#       'name': 'El Cafetin De Fernando VI',
#       'contact': {},
#       'location': {'address': 'Fernando VI',
#        'lat': 40.42484543685317,
#        'lng': -3.6957562579032963,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.42484543685317,
#          'lng': -3.6957562579032963}],
#        'distance': 381,
#        'cc': 'ES',
#        'city': 'Madrid',
#        'state': 'Madrid',
#        'country': 'España',
#        'formattedAddress': ['Fernando VI', 'Madrid Madrid', 'España']},
#       'categories': [{'id': '4bf58dd8d48988d16d941735',
#         'name': 'Café',
#         'pluralName': 'Cafés',
#         'shortName': 'Café',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': False,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'referralId': 'e-3-4d9c13139f86a1cde3b069ab-18'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '4e75e5b2e4cd32543782026f',
#       'name': 'Magasand Columela',
#       'contact': {},
#       'location': {'address': 'C. Columela, 4',
#        'lat': 40.421089,
#        'lng': -3.687984,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.421089,
#          'lng': -3.687984}],
#        'distance': 404,
#        'postalCode': '28001',
#        'cc': 'ES',
#        'city': 'Madrid',
#        'state': 'Madrid',
#        'country': 'España',
#        'formattedAddress': ['C. Columela, 4',
#         '28001 Madrid Madrid',
#         'España']},
#       'categories': [{'id': '4bf58dd8d48988d16d941735',
#         'name': 'Café',
#         'pluralName': 'Cafés',
#         'shortName': 'Café',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': False,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'referralId': 'e-3-4e75e5b2e4cd32543782026f-19'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '4cf6808cc020b60c90832075',
#       'name': 'Adolfo Dominguez Lounge Cafe',
#       'contact': {},
#       'location': {'address': 'C. Serrano, 5',
#        'crossStreet': 'C. Recoletos',
#        'lat': 40.421420464623246,
#        'lng': -3.6886059830484292,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.421420464623246,
#          'lng': -3.6886059830484292}],
#        'distance': 340,
#        'postalCode': '28001',
#        'cc': 'ES',
#        'city': 'Madrid',
#        'state': 'Madrid',
#        'country': 'España',
#        'formattedAddress': ['C. Serrano, 5 (C. Recoletos)',
#         '28001 Madrid Madrid',
#         'España']},
#       'categories': [{'id': '4bf58dd8d48988d16d941735',
#         'name': 'Café',
#         'pluralName': 'Cafés',
#         'shortName': 'Café',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': False,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'referralId': 'e-3-4cf6808cc020b60c90832075-20'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '4de78553d22dc38f1ee24b2b',
#       'name': 'El Supremo',
#       'contact': {},
#       'location': {'address': 'C. Marqués de la Ensenada',
#        'lat': 40.42384197017909,
#        'lng': -3.6928093295162947,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.42384197017909,
#          'lng': -3.6928093295162947}],
#        'distance': 137,
#        'postalCode': '28004',
#        'cc': 'ES',
#        'city': 'Madrid',
#        'state': 'Madrid',
#        'country': 'España',
#        'formattedAddress': ['C. Marqués de la Ensenada',
#         '28004 Madrid Madrid',
#         'España']},
#       'categories': [{'id': '4d4b7105d754a06374d81259',
#         'name': 'Food',
#         'pluralName': 'Food',
#         'shortName': 'Food',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': False,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'referralId': 'e-3-4de78553d22dc38f1ee24b2b-21'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '53c1b62a498eb5bf28f996bd',
#       'name': 'Mal de Amores',
#       'contact': {},
#       'location': {'address': 'Valgame Dios, 4',
#        'lat': 40.42225718566712,
#        'lng': -3.6966339163444717,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.42225718566712,
#          'lng': -3.6966339163444717}],
#        'distance': 372,
#        'cc': 'ES',
#        'country': 'España',
#        'formattedAddress': ['Valgame Dios, 4', 'España']},
#       'categories': [{'id': '4bf58dd8d48988d1c4941735',
#         'name': 'Restaurant',
#         'pluralName': 'Restaurants',
#         'shortName': 'Restaurant',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': False,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'referralId': 'e-3-53c1b62a498eb5bf28f996bd-22'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '5cf25b0406fb60002c8d15e5',
#       'name': 'Aarde',
#       'contact': {},
#       'location': {'lat': 40.419701,
#        'lng': -3.689125,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.419701,
#          'lng': -3.689125}],
#        'distance': 425,
#        'postalCode': '28014',
#        'cc': 'ES',
#        'city': 'Madrid',
#        'state': 'Madrid',
#        'country': 'España',
#        'formattedAddress': ['28014 Madrid Madrid', 'España']},
#       'categories': [{'id': '4bf58dd8d48988d1c0941735',
#         'name': 'Mediterranean Restaurant',
#         'pluralName': 'Mediterranean Restaurants',
#         'shortName': 'Mediterranean',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mediterranean_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': False,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'referralId': 'e-3-5cf25b0406fb60002c8d15e5-23'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '4b7274e2f964a5206a7b2de3',
#       'name': 'Ramsés',
#       'contact': {},
#       'location': {'address': 'Pl. de la Independencia, 4',
#        'lat': 40.420447280956324,
#        'lng': -3.6889526380636446,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.420447280956324,
#          'lng': -3.6889526380636446}],
#        'distance': 375,
#        'postalCode': '28001',
#        'cc': 'ES',
#        'city': 'Madrid',
#        'state': 'Madrid',
#        'country': 'España',
#        'formattedAddress': ['Pl. de la Independencia, 4',
#         '28001 Madrid Madrid',
#         'España']},
#       'categories': [{'id': '4bf58dd8d48988d1c4941735',
#         'name': 'Restaurant',
#         'pluralName': 'Restaurants',
#         'shortName': 'Restaurant',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': True,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'venuePage': {'id': '33840785'},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'referralId': 'e-3-4b7274e2f964a5206a7b2de3-24'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '4eb6e73102d5f33e9330b487',
#       'name': 'Food Truck',
#       'contact': {},
#       'location': {'address': 'C. San Lucas, 11',
#        'lat': 40.42381557557015,
#        'lng': -3.6960864532494018,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.42381557557015,
#          'lng': -3.6960864532494018}],
#        'distance': 346,
#        'cc': 'ES',
#        'city': 'Madrid',
#        'state': 'Madrid',
#        'country': 'España',
#        'formattedAddress': ['C. San Lucas, 11', 'Madrid Madrid', 'España']},
#       'categories': [{'id': '4bf58dd8d48988d14e941735',
#         'name': 'American Restaurant',
#         'pluralName': 'American Restaurants',
#         'shortName': 'American',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': False,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'referralId': 'e-3-4eb6e73102d5f33e9330b487-25'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '4adcda35f964a520873b21e3',
#       'name': 'El Cisne Azul',
#       'contact': {},
#       'location': {'address': 'C. Gravina, 19',
#        'lat': 40.4226125570602,
#        'lng': -3.696732565805115,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.4226125570602,
#          'lng': -3.696732565805115}],
#        'distance': 377,
#        'postalCode': '28004',
#        'cc': 'ES',
#        'neighborhood': 'Chueca',
#        'city': 'Madrid',
#        'state': 'Madrid',
#        'country': 'España',
#        'formattedAddress': ['C. Gravina, 19',
#         '28004 Madrid Madrid',
#         'España']},
#       'categories': [{'id': '4bf58dd8d48988d150941735',
#         'name': 'Spanish Restaurant',
#         'pluralName': 'Spanish Restaurants',
#         'shortName': 'Spanish',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/spanish_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': False,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'referralId': 'e-3-4adcda35f964a520873b21e3-26'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '51ca2035498e6098207e6624',
#       'name': 'Vides',
#       'contact': {},
#       'location': {'address': 'C. Libertad, 12',
#        'lat': 40.42101652377878,
#        'lng': -3.6973542003338395,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.42101652377878,
#          'lng': -3.6973542003338395}],
#        'distance': 468,
#        'postalCode': '28004',
#        'cc': 'ES',
#        'city': 'Madrid',
#        'state': 'Madrid',
#        'country': 'España',
#        'formattedAddress': ['C. Libertad, 12',
#         '28004 Madrid Madrid',
#         'España']},
#       'categories': [{'id': '4bf58dd8d48988d155941735',
#         'name': 'Gastropub',
#         'pluralName': 'Gastropubs',
#         'shortName': 'Gastropub',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/gastropub_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': False,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'referralId': 'e-3-51ca2035498e6098207e6624-27'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '550dd8d2498ecc23842fd54d',
#       'name': "Prep' La Crêpe",
#       'contact': {},
#       'location': {'address': 'C/ Génova, 25',
#        'lat': 40.42619324204986,
#        'lng': -3.692839342867028,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.42619324204986,
#          'lng': -3.692839342867028}],
#        'distance': 394,
#        'postalCode': '28004',
#        'cc': 'ES',
#        'city': 'Madrid',
#        'state': 'Madrid',
#        'country': 'España',
#        'formattedAddress': ['C/ Génova, 25', '28004 Madrid Madrid', 'España']},
#       'categories': [{'id': '52e81612bcbc57f1066b79f2',
#         'name': 'Creperie',
#         'pluralName': 'Creperies',
#         'shortName': 'Creperie',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/creperie_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': True,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'venuePage': {'id': '580424930'},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'referralId': 'e-3-550dd8d2498ecc23842fd54d-28'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '59bd2433805e3f5982c09476',
#       'name': "Bunny's Deli",
#       'contact': {},
#       'location': {'address': 'Calle San Gregorio 17',
#        'lat': 40.423935,
#        'lng': -3.6971583,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.423935,
#          'lng': -3.6971583}],
#        'distance': 436,
#        'postalCode': '28004',
#        'cc': 'ES',
#        'neighborhood': 'Chueca',
#        'city': 'Madrid',
#        'state': 'Madrid',
#        'country': 'España',
#        'formattedAddress': ['Calle San Gregorio 17',
#         '28004 Madrid Madrid',
#         'España']},
#       'categories': [{'id': '4bf58dd8d48988d1d3941735',
#         'name': 'Vegetarian / Vegan Restaurant',
#         'pluralName': 'Vegetarian / Vegan Restaurants',
#         'shortName': 'Vegetarian / Vegan',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': True,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'venuePage': {'id': '457440977'},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'referralId': 'e-3-59bd2433805e3f5982c09476-29'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '59452002061b51682cee99b8',
#       'name': 'Canalla Bistro by Ricard Camarena',
#       'contact': {},
#       'location': {'address': 'C. Goya, 5-7, Planta 1',
#        'lat': 40.426057373983376,
#        'lng': -3.688617396245811,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.426057373983376,
#          'lng': -3.688617396245811}],
#        'distance': 487,
#        'postalCode': '28001',
#        'cc': 'ES',
#        'city': 'Madrid',
#        'state': 'Madrid',
#        'country': 'España',
#        'formattedAddress': ['C. Goya, 5-7, Planta 1',
#         '28001 Madrid Madrid',
#         'España']},
#       'categories': [{'id': '4bf58dd8d48988d1c4941735',
#         'name': 'Restaurant',
#         'pluralName': 'Restaurants',
#         'shortName': 'Restaurant',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': False,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'referralId': 'e-3-59452002061b51682cee99b8-30'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '5c44a7dd57a537002c8bf697',
#       'name': 'Aüakt',
#       'contact': {},
#       'location': {'lat': 40.424315,
#        'lng': -3.695449,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.424315,
#          'lng': -3.695449}],
#        'distance': 324,
#        'postalCode': '28004',
#        'cc': 'ES',
#        'city': 'Madrid',
#        'state': 'Madrid',
#        'country': 'España',
#        'formattedAddress': ['28004 Madrid Madrid', 'España']},
#       'categories': [{'id': '4bf58dd8d48988d16d941735',
#         'name': 'Café',
#         'pluralName': 'Cafés',
#         'shortName': 'Café',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': False,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'referralId': 'e-3-5c44a7dd57a537002c8bf697-31'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '5b9fa92ead1789002c610c90',
#       'name': 'Roots',
#       'contact': {},
#       'location': {'address': 'C. Fernando VI',
#        'lat': 40.424572,
#        'lng': -3.6955872,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.424572,
#          'lng': -3.6955872}],
#        'distance': 351,
#        'postalCode': '28004',
#        'cc': 'ES',
#        'neighborhood': 'Chueca',
#        'city': 'Madrid',
#        'state': 'Madrid',
#        'country': 'España',
#        'formattedAddress': ['C. Fernando VI',
#         '28004 Madrid Madrid',
#         'España']},
#       'categories': [{'id': '4bf58dd8d48988d1d3941735',
#         'name': 'Vegetarian / Vegan Restaurant',
# ...
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '55cb69be498e3c20da3ef6f5',
#       'name': 'Boho Bar',
#       'contact': {},
#       'location': {'address': 'C. Colmenares, 13',
#        'crossStreet': 'C. San Marcos',
#        'lat': 40.42119008484262,
#        'lng': -3.696839788805677,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.42119008484262,
#          'lng': -3.696839788805677}],
#        'distance': 420,
#        'postalCode': '28004',
#        'cc': 'ES',
#        'city': 'Madrid',
#        'state': 'Madrid',
#        'country': 'España',
#        'formattedAddress': ['C. Colmenares, 13 (C. San Marcos)',
#         '28004 Madrid Madrid',
#         'España']},
#       'categories': [{'id': '4bf58dd8d48988d1c4941735',
#         'name': 'Restaurant',
#         'pluralName': 'Restaurants',
#         'shortName': 'Restaurant',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': False,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'referralId': 'e-3-55cb69be498e3c20da3ef6f5-89'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '4b75e1eff964a520e02b2ee3',
#       'name': 'Restaurante Arce',
#       'contact': {},
#       'location': {'address': 'C. Augusto Figueroa, 32',
#        'lat': 40.42207258933475,
#        'lng': -3.6967412061319482,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.42207258933475,
#          'lng': -3.6967412061319482}],
#        'distance': 384,
#        'postalCode': '28004',
#        'cc': 'ES',
#        'city': 'Madrid',
#        'state': 'Madrid',
#        'country': 'España',
#        'formattedAddress': ['C. Augusto Figueroa, 32',
#         '28004 Madrid Madrid',
#         'España']},
#       'categories': [{'id': '4bf58dd8d48988d150941735',
#         'name': 'Spanish Restaurant',
#         'pluralName': 'Spanish Restaurants',
#         'shortName': 'Spanish',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/spanish_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': False,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'referralId': 'e-3-4b75e1eff964a520e02b2ee3-90'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '591ffe425d0fea5ae1445497',
#       'name': 'Aloha Poké',
#       'contact': {},
#       'location': {'address': 'Calle de la Libertad 17',
#        'lat': 40.42113511381703,
#        'lng': -3.6973795495793205,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.42113511381703,
#          'lng': -3.6973795495793205}],
#        'distance': 465,
#        'postalCode': '28004',
#        'cc': 'ES',
#        'city': 'Madrid',
#        'state': 'Madrid',
#        'country': 'España',
#        'formattedAddress': ['Calle de la Libertad 17',
#         '28004 Madrid Madrid',
#         'España']},
#       'categories': [{'id': '52e81612bcbc57f1066b79fe',
#         'name': 'Hawaiian Restaurant',
#         'pluralName': 'Hawaiian Restaurants',
#         'shortName': 'Hawaiian',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': True,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'venuePage': {'id': '423049614'},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'referralId': 'e-3-591ffe425d0fea5ae1445497-91'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '5650e689498e59806e43a30f',
#       'name': 'Ôven Mozzarella Bar',
#       'contact': {},
#       'location': {'address': 'Calle Gran Via, 6',
#        'lat': 40.41924524133954,
#        'lng': -3.6978500877927485,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.41924524133954,
#          'lng': -3.6978500877927485}],
#        'distance': 607,
#        'postalCode': '28013',
#        'cc': 'ES',
#        'city': 'Madrid',
#        'state': 'Madrid',
#        'country': 'España',
#        'formattedAddress': ['Calle Gran Via, 6',
#         '28013 Madrid Madrid',
#         'España']},
#       'categories': [{'id': '4bf58dd8d48988d110941735',
#         'name': 'Italian Restaurant',
#         'pluralName': 'Italian Restaurants',
#         'shortName': 'Italian',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': False,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'referralId': 'e-3-5650e689498e59806e43a30f-92'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '57ee650fcd1039e6f39b65f8',
#       'name': 'Tampu',
#       'contact': {},
#       'location': {'address': 'C. Prim, 13',
#        'lat': 40.42199569954899,
#        'lng': -3.693545458260162,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.42199569954899,
#          'lng': -3.693545458260162}],
#        'distance': 131,
#        'cc': 'ES',
#        'country': 'España',
#        'formattedAddress': ['C. Prim, 13', 'España']},
#       'categories': [{'id': '4bf58dd8d48988d1c4941735',
#         'name': 'Restaurant',
#         'pluralName': 'Restaurants',
#         'shortName': 'Restaurant',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': False,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'referralId': 'e-3-57ee650fcd1039e6f39b65f8-93'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '4adcda3af964a5205b3d21e3',
#       'name': 'Arabia',
#       'contact': {},
#       'location': {'address': 'c/ Piamonte, 12',
#        'lat': 40.42305,
#        'lng': -3.6950688,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.42305,
#          'lng': -3.6950688}],
#        'distance': 240,
#        'postalCode': '28004',
#        'cc': 'ES',
#        'neighborhood': 'Chueca',
#        'city': 'Madrid',
#        'state': 'Madrid',
#        'country': 'España',
#        'formattedAddress': ['c/ Piamonte, 12',
#         '28004 Madrid Madrid',
#         'España']},
#       'categories': [{'id': '4bf58dd8d48988d1c3941735',
#         'name': 'Moroccan Restaurant',
#         'pluralName': 'Moroccan Restaurants',
#         'shortName': 'Moroccan',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/moroccan_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': False,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'referralId': 'e-3-4adcda3af964a5205b3d21e3-94'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '4b842bf2f964a5205b2531e3',
#       'name': 'La Castafiore',
#       'contact': {},
#       'location': {'address': 'C. Marqués de Monasterio, 5',
#        'lat': 40.4231948184309,
#        'lng': -3.6934970747678526,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.4231948184309,
#          'lng': -3.6934970747678526}],
#        'distance': 118,
#        'postalCode': '28004',
#        'cc': 'ES',
#        'city': 'Madrid',
#        'state': 'Madrid',
#        'country': 'España',
#        'formattedAddress': ['C. Marqués de Monasterio, 5',
#         '28004 Madrid Madrid',
#         'España']},
#       'categories': [{'id': '4bf58dd8d48988d1c4941735',
#         'name': 'Restaurant',
#         'pluralName': 'Restaurants',
#         'shortName': 'Restaurant',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': False,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'referralId': 'e-3-4b842bf2f964a5205b2531e3-95'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '538ce5df498eb2165bface85',
#       'name': 'Yakitoro',
#       'contact': {},
#       'location': {'address': 'C. de la Reina, 41',
#        'lat': 40.419647701387746,
#        'lng': -3.697201837743589,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.419647701387746,
#          'lng': -3.697201837743589}],
#        'distance': 536,
#        'postalCode': '28001',
#        'cc': 'ES',
#        'city': 'Madrid',
#        'state': 'Madrid',
#        'country': 'España',
#        'formattedAddress': ['C. de la Reina, 41',
#         '28001 Madrid Madrid',
#         'España']},
#       'categories': [{'id': '4bf58dd8d48988d111941735',
#         'name': 'Japanese Restaurant',
#         'pluralName': 'Japanese Restaurants',
#         'shortName': 'Japanese',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': False,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'referralId': 'e-3-538ce5df498eb2165bface85-96'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '5710f195498e1bdf3422620a',
#       'name': 'cripeka',
#       'contact': {},
#       'location': {'lat': 40.42633069472612,
#        'lng': -3.696475115325826,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.42633069472612,
#          'lng': -3.696475115325826}],
#        'distance': 540,
#        'cc': 'ES',
#        'country': 'España',
#        'formattedAddress': ['España']},
#       'categories': [{'id': '4bf58dd8d48988d16a941735',
#         'name': 'Bakery',
#         'pluralName': 'Bakeries',
#         'shortName': 'Bakery',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': False,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'referralId': 'e-3-5710f195498e1bdf3422620a-97'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '531f8e56498e6a649718295b',
#       'name': 'La Mafia se sienta a la mesa',
#       'contact': {},
#       'location': {'address': 'C. Goya, 5',
#        'lat': 40.425704898432215,
#        'lng': -3.688945279786655,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.425704898432215,
#          'lng': -3.688945279786655}],
#        'distance': 439,
#        'postalCode': '28001',
#        'cc': 'ES',
#        'city': 'Madrid',
#        'state': 'Madrid',
#        'country': 'España',
#        'formattedAddress': ['C. Goya, 5', '28001 Madrid Madrid', 'España']},
#       'categories': [{'id': '4bf58dd8d48988d110941735',
#         'name': 'Italian Restaurant',
#         'pluralName': 'Italian Restaurants',
#         'shortName': 'Italian',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': False,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'referralId': 'e-3-531f8e56498e6a649718295b-98'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '554e686d498e1d5fa7d64d0c',
#       'name': 'Mandarin Japanese Kitchen',
#       'contact': {},
#       'location': {'address': 'Paseo De Recoletos, 37',
#        'lat': 40.42434371838993,
#        'lng': -3.6913664650128597,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.42434371838993,
#          'lng': -3.6913664650128597}],
#        'distance': 200,
#        'cc': 'ES',
#        'city': 'Madrid',
#        'state': 'Madrid',
#        'country': 'España',
#        'formattedAddress': ['Paseo De Recoletos, 37',
#         'Madrid Madrid',
#         'España']},
#       'categories': [{'id': '4bf58dd8d48988d111941735',
#         'name': 'Japanese Restaurant',
#         'pluralName': 'Japanese Restaurants',
#         'shortName': 'Japanese',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': False,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'referralId': 'e-3-554e686d498e1d5fa7d64d0c-99'}]}]}

# %%
data["response"]['groups'][0].keys()
# Out:
# dict_keys(['type', 'name', 'items'])

# %%
data["response"]['groups'][0]["items"][0].keys()
# Out:
# dict_keys(['reasons', 'venue', 'referralId'])

# %%
data["response"]['groups'][0]["items"][0]["venue"]
# Out:
# {'id': '5ac924f0a22db76045072b51',
#  'name': 'Charrua',
#  'contact': {},
#  'location': {'lat': 40.422416,
#   'lng': -3.693999,
#   'labeledLatLngs': [{'label': 'display', 'lat': 40.422416, 'lng': -3.693999}],
#   'distance': 148,
#   'postalCode': '28004',
#   'cc': 'ES',
#   'city': 'Madrid',
#   'state': 'Madrid',
#   'country': 'España',
#   'formattedAddress': ['28004 Madrid Madrid', 'España']},
#  'categories': [{'id': '4bf58dd8d48988d1df931735',
#    'name': 'BBQ Joint',
#    'pluralName': 'BBQ Joints',
#    'shortName': 'BBQ',
#    'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#     'suffix': '.png'},
#    'primary': True}],
#  'verified': False,
#  'stats': {'tipCount': 0,
#   'usersCount': 0,
#   'checkinsCount': 0,
#   'visitsCount': 0},
#  'beenHere': {'count': 0,
#   'lastCheckinExpiredAt': 0,
#   'marked': False,
#   'unconfirmedCount': 0},
#  'photos': {'count': 0, 'groups': []},
#  'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}}

# %%
data["response"]['groups'][0]["items"][0]["venue"]['name']
# Out:
# 'Charrua'

# %%
for rest in data["response"]['groups'][0]["items"]:
    print(rest["venue"]["name"])
# Out:
# Charrua
# Cannibal Raw Bar
# Pelotari
# Doki Doki
# la vaca y la huerta
# New York Burger
# Flavia Restaurante & Bar
# Panod
# celicioso
# Raimunda
# Banzai
# DSTAgE
# Mamá Chicó
# Habanera
# niMÚ Barquillo
# La Tavernetta
# a.n.E.l. Tapas & Lounge Bar
# Faborit
# El Cafetin De Fernando VI
# Magasand Columela
# Adolfo Dominguez Lounge Cafe
# El Supremo
# Mal de Amores
# Aarde
# Ramsés
# Food Truck
# El Cisne Azul
# Vides
# Prep' La Crêpe
# Bunny's Deli
# Canalla Bistro by Ricard Camarena
# Aüakt
# Roots
# Sr. Ito
# La Candelita
# Shuwa Shuwa
# 99 Sushi Bar
# Honest Greens
# Roostiq
# Barrutia
# Morgana
# Krachai
# La Bien Aparecida
# La Panaderia de Chueca
# Thai Orchid
# Mallorca Market
# Platea Madrid
# La Maquina Jorge Juan
# El Perro y La Galleta
# El Paraguas
# La Magdalena De Proust
# Mad Grill
# Alabaster
# Kuoco 360
# García de La Navarra
# Tienda de Vinos (El Comunista)
# Pink Monkey
# Celso y Manolo
# La Giralda IV
# La alacena de Victor Montes (mercado de San Anton)
# La Garriga
# Quispe
# Cafés Arrivederci
# Alfredo's Barbacoa
# La Primera
# La Galette 2 - Casa Escondida
# il Tavolo Verde
# Pizzaiolo
# Café de París, L' Entrecot
# Capperi Mercato Italiano
# Restaurante Vegaviana
# La Carmencita
# Petit Appetit
# Amazónico
# Ultramarinos Quintin
# Al-Mounia
# Bocadillo de Jamón y Champán
# Horcher
# Shikku
# Hard Rock Cafe Madrid
# Fit Food
# Vinitus
# Mestizo
# Trattoria Pulcinella
# Magasand
# La Senda De Xiquena
# Hot Now
# Diurno Restaurant & Bar
# La Buha
# Boho Bar
# Restaurante Arce
# Aloha Poké
# Ôven Mozzarella Bar
# Tampu
# Arabia
# La Castafiore
# Yakitoro
# cripeka
# La Mafia se sienta a la mesa
# Mandarin Japanese Kitchen

# %%
opciones = [rest["venue"]["name"] for rest in data["response"]['groups'][0]["items"]]
opciones
# Out:
# ['Charrua',
#  'Cannibal Raw Bar',
#  'Pelotari',
#  'Doki Doki',
#  'la vaca y la huerta',
#  'New York Burger',
#  'Flavia Restaurante & Bar',
#  'Panod',
#  'celicioso',
#  'Raimunda',
#  'Banzai',
#  'DSTAgE',
#  'Mamá Chicó',
#  'Habanera',
#  'niMÚ Barquillo',
#  'La Tavernetta',
#  'a.n.E.l. Tapas & Lounge Bar',
#  'Faborit',
#  'El Cafetin De Fernando VI',
#  'Magasand Columela',
#  'Adolfo Dominguez Lounge Cafe',
#  'El Supremo',
#  'Mal de Amores',
#  'Aarde',
#  'Ramsés',
#  'Food Truck',
#  'El Cisne Azul',
#  'Vides',
#  "Prep' La Crêpe",
#  "Bunny's Deli",
#  'Canalla Bistro by Ricard Camarena',
#  'Aüakt',
#  'Roots',
#  'Sr. Ito',
#  'La Candelita',
#  'Shuwa Shuwa',
#  '99 Sushi Bar',
#  'Honest Greens',
#  'Roostiq',
#  'Barrutia',
#  'Morgana',
#  'Krachai',
#  'La Bien Aparecida',
#  'La Panaderia de Chueca',
#  'Thai Orchid',
#  'Mallorca Market',
#  'Platea Madrid',
#  'La Maquina Jorge Juan',
#  'El Perro y La Galleta',
#  'El Paraguas',
#  'La Magdalena De Proust',
#  'Mad Grill',
#  'Alabaster',
#  'Kuoco 360',
#  'García de La Navarra',
#  'Tienda de Vinos (El Comunista)',
#  'Pink Monkey',
#  'Celso y Manolo',
#  'La Giralda IV',
#  'La alacena de Victor Montes (mercado de San Anton)',
#  'La Garriga',
#  'Quispe',
#  'Cafés Arrivederci',
#  "Alfredo's Barbacoa",
#  'La Primera',
#  'La Galette 2 - Casa Escondida',
#  'il Tavolo Verde',
#  'Pizzaiolo',
#  "Café de París, L' Entrecot",
#  'Capperi Mercato Italiano',
#  'Restaurante Vegaviana',
#  'La Carmencita',
#  'Petit Appetit',
#  'Amazónico',
#  'Ultramarinos Quintin',
#  'Al-Mounia',
#  'Bocadillo de Jamón y Champán',
#  'Horcher',
#  'Shikku',
#  'Hard Rock Cafe Madrid',
#  'Fit Food',
#  'Vinitus',
#  'Mestizo',
#  'Trattoria Pulcinella',
#  'Magasand',
#  'La Senda De Xiquena',
#  'Hot Now',
#  'Diurno Restaurant & Bar',
#  'La Buha',
#  'Boho Bar',
#  'Restaurante Arce',
#  'Aloha Poké',
#  'Ôven Mozzarella Bar',
#  'Tampu',
#  'Arabia',
#  'La Castafiore',
#  'Yakitoro',
#  'cripeka',
#  'La Mafia se sienta a la mesa',
#  'Mandarin Japanese Kitchen']

# %% [markdown]
# Comprobamos que efectivamente están cerca de **The Bridge**

# %% [markdown]
# - **Charrua**

# %% [markdown]
# https://www.google.com/maps/place/Charr%C3%BAa+Madrid/@40.4213206,-3.6974034,15z/data=!4m5!3m4!1s0x0:0x8673b16903da6e51!8m2!3d40.4223987!4d-3.6940989

# %% [markdown]
# - **Pelotari**

# %% [markdown]
# https://www.google.com/maps/place/Pelotari/@40.4210322,-3.7011421,15.06z/data=!4m8!1m2!2m1!1spelotari!3m4!1s0xd42289a8d2d74cb:0x2b6420709612ce53!8m2!3d40.4222232!4d-3.6906525

# %% [markdown]
# - **Doki doki**

# %% [markdown]
# https://www.google.com/maps/place/Restaurante+Doki+Doki/@40.421046,-3.6919977,17z/data=!3m1!4b1!4m5!3m4!1s0xd42289a5313ac17:0x27cfb02077407a64!8m2!3d40.421046!4d-3.689809
