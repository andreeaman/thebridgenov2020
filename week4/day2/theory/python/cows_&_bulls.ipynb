# %% [markdown]
# - [Cows_and_Bulls]
#
# Say the number generated by the computer is 1038. An example interaction could look like this:
#
#   Welcome to the Cows and Bulls Game!
#
#   >Enter a number:
#
#   >> 1234
#
#   >>> 2 cows, 0 bulls
#
#   >> 1253
#
#   >>> 1 cow, 1 bull
#
#   ...
# Until the user guesses the number or write "STOP"

# %%
import random
print ("Welcome to the Cows and Bulls Game!")


def cows_bulls(num):
          
    listnum = [random.randint(0,9) for n in range(num)]
    random_num=''
    for elem in listnum:
        random_num += str(elem)
    else:
        #pass
        print("for thesting purposes :)! Ramdon number is:" + random_num)
    
    acum=0
    while True:
        acum+=1
        print("Enter a " + str(num) + "-digit number: ")
        guess = [int(i) for i in str(input("Enter a number:"))]
        answer=''
        for elem in guess:
            answer += str(elem)
        else:
            print("Your answer is:" + answer)

        if answer == "STOP":
            print("the user gave up!")
            print ("the correct answer is:"+ random_num)
            break
        elif guess == listnum:
            print("You guessed the number.")
            print("It took you "+str(acum)+" guess(es).")
            break


        else:
            cow=0
            bull=0

            for x in range(0,num):
                if guess[x]==listnum[x]:
                    cow += 1
                elif guess[x] in listnum:1
                bull += 1
    
        print(str(cow)+" cows, "+ str(bull)+ " bulls")
        print("---------------")

cows_bulls(4)
# Out:
# Welcome to the Cows and Bulls Game!
# for thesting purposes :)! Ramdon number is:5701
# Enter a 4-digit number:
# Your answer is:2356
# 0 cows, 4 bulls
# ---------------
# Enter a 4-digit number:
# Your answer is:5701
# You guessed the number.
# It took you 2 guess(es).
