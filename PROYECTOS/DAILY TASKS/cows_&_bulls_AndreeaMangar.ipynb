# %% [markdown]
# - [Cows_and_Bulls]
#
# Say the number generated by the computer is 1038. An example interaction could look like this:
#
#   Welcome to the Cows and Bulls Game!
#
#   >Enter a number:
#
#   >> 1234
#
#   >>> 2 cows, 0 bulls
#
#   >> 1253
#
#   >>> 1 cow, 1 bull
#
#   ...
# Until the user guesses the number or write "STOP"

# %%
import random
print ("Welcome to the Cows and Bulls Game!")


def cows_bulls(num):
   
    listnum = [random.randint(0,9) for n in range(num)]
    print("Random number = " + str(listnum)
    
    acum = 0
    while True:
        acum+=1
        print("Enter a " + str(num) + "-digit number: ")
        guess = [int(i) for i in str(input("Enter a number:"))]
        for element in guess:
        result += str(element)

        
        if guess == listnum:
            print("You guessed the number.")
            print("It took you "+str(acum)+" guess(es).")
            break

        else:
            cow=0
            bull=0

            for x in range(0,num):
                if guess[x]==listnum[x]:
                    cow += 1
                elif guess[x] in listnum:1
                bull += 1
    
        print(str(cow)+" cows, "+ str(bull)+ " bulls")
        print("---------------")

cows_bulls(4)

def concatenate_list_data(guess):
    result= ''
    for element in list:
        result += str(element)
    return result

concatenate_list_data(guess)
# Out:
#   File "<ipython-input-1-5ecba1f46cd3>", line 10
#     acum = 0
#     ^
# SyntaxError: invalid syntax
