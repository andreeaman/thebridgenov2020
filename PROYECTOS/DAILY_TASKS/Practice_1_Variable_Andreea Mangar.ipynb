# %% [markdown]
# # Python | day 1 | variables

# %% [markdown]
# Variables are nothing but reserved memory locations to store values. This means that when you create a variable you reserve some space in memory.
#
# Based on the data type of a variable, the interpreter allocates memory and decides what can be stored in the reserved memory. Therefore, by assigning different data types to variables, you can store integers, decimals or characters in these variables.

# %% [markdown]
# ### Exercise 1.
#
# 1. Write a python comment saying _'My very first python code:'_

# %%
print ('my very first python code:')
# Out:
# my very first python code:

# %% [markdown]
# 2. Declare a **first name** variable and assign a value to it

# %%
first_name = "Andreea"
print (first_name)
# Out:
# Andreea

# %% [markdown]
# 3. Declare a **last name** variable and assign a value to it

# %%
last_name = "Mangâr"
print (last_name)
# Out:
# Mangâr

# %% [markdown]
# 4. Declare a **full name** variable and assign a value to it

# %%
full_name = first_name + " " + last_name
print (full_name)
# Out:
# Andreea Mangâr

# %% [markdown]
# 5. Declare a **country** variable and assign a value to it

# %%
country = "Espana"
print (country)
# Out:
# Espana

# %% [markdown]
# 6. Declare a **city** variable and assign a value to it

# %%
city = "Madrid"

# %% [markdown]
# 7. Declare an **age** variable and assign a value to it

# %%
age = 37

# %% [markdown]
# 8. Declare a **year** variable and assign a value to it

# %%
year = 2020

# %% [markdown]
# 9. Declare a variable **is_married** and assign a value to it

# %%
is_married = false
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-952926825743> in <module>
# ----> 1 is_married = false
#
# NameError: name 'false' is not defined

# %% [markdown]
# 10. Declare a variable **is_true** and assign a value to it

# %% [markdown]
# 11. Declare a variable **is_light_on** and assign a value to it

# %% [markdown]
# ## Exercise 2.
#
# 1. Check the data type of all your variables using `type()` built-in function

# %%
print ("first_name", first_name , type(first_name))
print ("last_name", last_name , type(last_name))
print ("city", city , type(city))
print ("country", country , type(country))
print ("age", age , type(age))
print ("year", year , type(year))
# Out:
# first_name Andreea <class 'str'>
# last_name Mangâr <class 'str'>
# city Madrid <class 'str'>
# country Espana <class 'str'>
# age 37.0 <class 'float'>
# year 2020 <class 'int'>

# %% [markdown]
# Turn the variable **age**, which should be *integer*, into type *float*. This action is known as cast a variable.

# %%
age = float (age)
print (type (age))
# Out:
# <class 'float'>

# %% [markdown]
# 2. Using the `len()` built-in function find the length of your first name

# %%
print (len(first_name))
# Out:
# 7

# %% [markdown]
# 3. Compare the length of your first name and your last name

# %%
print (first_name, len(first_name), last_name, len(last_name))
# Out:
# Andreea 7 Mangâr 6

# %% [markdown]
# 4. Declare 5 as **num_one** and 4 as **num_two**

# %%
num_one = 5
num_two = 4

# %% [markdown]
# 5. Add **num_one** and **num_two** and assign the value to a variable **_total**

# %%
variable_total = num_one + num_two
print ("variable_total=", variable_total)
# Out:
# variable_total= 9

# %% [markdown]
# 6. Subtract num_two from num_one and assign the value to a variable _diff

# %%
variable_diff = num_one - num_two
print ("variable_diff=",variable_diff)
# Out:
# variable_diff= 1

# %% [markdown]
# 7. Multiply **num_two** and **num_one** and assign the value to a variable **_product**

# %%
variable_product = num_one * num_two
print ("variable_product=",variable_product)
# Out:
# variable_product= 20

# %% [markdown]
# 8. Divide **num_one** by **num_two** and assign the value to a variable **_division**

# %%
variable_division = num_one / num_two
print ("variable_division=",variable_division)
# Out:
# variable_division= 1.25
# <class 'float'>

# %% [markdown]
# 9. Use modulus division to find **num_two** divided by **num_one** and assign the value to a variable **_remainder**

# %%
variable_remainder = num_one % num_two
print ("variable_remainder=",variable_remainder)
# Out:
# variable_remainder= 1

# %% [markdown]
# 10. Calculate **num_one** to the power of **num_two** and assign the value to variable **_exp**

# %%
variable_exp = num_one ** num_two
print ("variable_exp=",variable_exp)
# Out:
# variable_exp= 625

# %% [markdown]
# 11. Find floor division of **num_one** by **num_two** and assign the value to a variable **_floor_division**

# %%
variable_floor_division = num_one // num_two
print ("variable_floor_division=",variable_floor_division)
# Out:
# variable_floor_division= 1

# %% [markdown]
# ## Bonus track.

# %% [markdown]
# 12. The radius of a circle is 30 meters.
#     Calculate the area of a circle and assign the value to a variable **area_of_circle**

# %%
radius = 30
pi = 3.141592653589793
area_of_circle = pi * (radius ** 2)
print (area_of_circle)
# Out:
# 2827.4333882308138

# %% [markdown]
# 13. Calculate the circumference of a circle and assign the value to a variable **circum_of_circle**

# %%
circum_of_circle = 2 * pi * radius
print (circum_of_circle)
# Out:
# 188.49555921538757

# %% [markdown]
# 14. Take radius as user input and calculate the area.

# %%
# no se como ponerlo para que recoga tambien valores float
radius_user = input ("Please enter radius:")
radius_user = int (radius_user)

area_user = pi * (radius_user ** 2)
print (area_user)
# Out:
# 12.566370614359172

# %% [markdown]
# 15. Use the built-in input function to get first name, last name, country and age from a user and store the value to their corresponding variable names

# %%
first_name_user = input ("Please enter your first name:")
last_name_user = input ("Please enter your last name:")
country_user = input ("Please enter country:")
age_user = input ("Please enter your age:")

print ("First name:", first_name_user)
print ("Last name:", last_name_user)
print ("Country:", country_user)
print ("Aged:", age_user)
# Out:
# First name: andreea
# Last name: mangar
# Country: espana
# Aged: 37

# %% [markdown]
# 16. What is a reserved word in Python? Run `help('keywords')` to check for the reserved words.

# %%
# reserved words : print, type, etc.

# %% [markdown]
# **Well done!**

# %% [markdown]
# ![h](https://i.pinimg.com/originals/11/b4/20/11b420fbf1595be3056ad6355277933c.jpg)
